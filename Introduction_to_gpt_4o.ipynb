# %% [markdown]
# <a href="https://colab.research.google.com/github/elichen/oai-playground/blob/main/Introduction_to_gpt_4o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata

# %%
# %pip install --upgrade openai --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.1/328.1 kB 2.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.2 MB/s eta 0:00:00

# %%
from openai import OpenAI
import os

## Set the API key and model name
MODEL="gpt-4o"
client = OpenAI(api_key=userdata.get('openai-key'))

# %%
completion = client.chat.completions.create(
  model=MODEL,
  messages=[
    {"role": "system", "content": "You are a helpful assistant. Help me with my math homework!"}, # <-- This is the system message that provides context to the model
    {"role": "user", "content": "Hello! Could you solve 2+2?"}  # <-- This is the user message for which the model will generate a response
  ]
)

print("Assistant: " + completion.choices[0].message.content)
# Out:
# Assistant: Of course! The sum of 2 + 2 is 4. If you have any more questions or need further help, feel free to ask!

# %%
from IPython.display import Image, display
import base64

# Base64 string for the image
base64_string = "..."

# Decode the base64 string
image_data = base64.b64decode(base64_string)

# Display the image
display(Image(data=image_data))

# %%
response = client.chat.completions.create(
    model=MODEL,
    messages=[
        {"role": "system", "content": "You are a helpful assistant that responds in Markdown. Help me with my math homework!"},
        {"role": "user", "content": [
            {"type": "text", "text": "What's the area of the triangle?"},
            {"type": "image_url", "image_url": {
                "url": f"data:image/png;base64,{base64_string}"}
            }
        ]}
    ],
    temperature=0.0,
)

print(response.choices[0].message.content)
# Out:
# To find the area of the triangle, we can use Heron's formula. First, we need to find the semi-perimeter of the triangle.
#
# The sides of the triangle are 6, 5, and 9.
#
# 1. Calculate the semi-perimeter \( s \):
# \[ s = \frac{a + b + c}{2} = \frac{6 + 5 + 9}{2} = 10 \]
#
# 2. Use Heron's formula to find the area \( A \):
# \[ A = \sqrt{s(s-a)(s-b)(s-c)} \]
#
# Substitute the values:
# \[ A = \sqrt{10(10-6)(10-5)(10-9)} \]
# \[ A = \sqrt{10 \cdot 4 \cdot 5 \cdot 1} \]
# \[ A = \sqrt{200} \]
# \[ A = 10\sqrt{2} \]
#
# So, the area of the triangle is \( 10\sqrt{2} \) square units.

# %%
response = client.chat.completions.create(
    model=MODEL,
    messages=[
        {"role": "system", "content": "You are a helpful assistant that responds in Markdown. Help me with my math homework!"},
        {"role": "user", "content": [
            {"type": "text", "text": "What's the area of the triangle?"},
            {"type": "image_url", "image_url": {
                "url": "https://upload.wikimedia.org/wikipedia/commons/e/e2/The_Algebra_of_Mohammed_Ben_Musa_-_page_82b.png"}
            }
        ]}
    ],
    temperature=0.0,
)

print(response.choices[0].message.content)
# Out:
# To find the area of the triangle, we can use Heron's formula. First, we need to find the semi-perimeter of the triangle.
#
# The sides of the triangle are 6, 5, and 9.
#
# 1. Calculate the semi-perimeter \( s \):
# \[ s = \frac{a + b + c}{2} = \frac{6 + 5 + 9}{2} = 10 \]
#
# 2. Use Heron's formula to find the area \( A \):
# \[ A = \sqrt{s(s-a)(s-b)(s-c)} \]
#
# Substitute the values:
# \[ A = \sqrt{10(10-6)(10-5)(10-9)} \]
# \[ A = \sqrt{10 \cdot 4 \cdot 5 \cdot 1} \]
# \[ A = \sqrt{200} \]
# \[ A = 10\sqrt{2} \]
#
# So, the area of the triangle is \( 10\sqrt{2} \) square units.

# %%
response = client.chat.completions.create(
    model=MODEL,
    messages=[
        {"role": "system", "content": "You are a helpful and smart assistant."},
        {"role": "user", "content": [
            {"type": "text", "text": "Explain this meme"},
            {"type": "image_url", "image_url": {
                "url": "https://pbs.twimg.com/media/GPhJAdOaUAAoBhi?format=jpg&name=medium"}
            }
        ]}
    ],
    temperature=0.0,
)

print(response.choices[0].message.content)
# Out:
# This meme uses a common format to depict a situation where one person or group is receiving a large amount of something, while another person or group is receiving very little.
#
# In this specific meme:
# - The large, well-fed person labeled "Jensen Huang" is receiving a large flow of liquid from a pipe labeled "Asian Baddies."
# - The small, emaciated person labeled "Me" is receiving only a few drops from the same pipe.
#
# The humor in the meme comes from the exaggerated disparity between the two characters. It suggests that Jensen Huang (a prominent figure, likely referring to the CEO of NVIDIA) is getting a lot of attention or benefits from "Asian Baddies," while the person labeled "Me" is getting almost nothing. This could be a humorous commentary on the perceived imbalance in attention or resources between the two parties.

# %%
# %pip install opencv-python --quiet
# %pip install moviepy --quiet

# %%
import requests
import cv2
from moviepy.editor import VideoFileClip
import time
import base64

# We'll be using the OpenAI DevDay Keynote Recap video. You can review the video here: https://www.youtube.com/watch?v=h02ti0Bl6zk
VIDEO_URL = "http://commondatastorage.googleapis.com/gtv-videos-bucket/sample/ForBiggerBlazes.mp4"
response = requests.get(VIDEO_URL)
VIDEO_PATH = "video.mp4"
with open(VIDEO_PATH, 'wb') as file:
    file.write(response.content)

# %%
def process_video(video_path, seconds_per_frame=2):
    base64Frames = []
    base_video_path, _ = os.path.splitext(video_path)

    video = cv2.VideoCapture(video_path)
    total_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
    fps = video.get(cv2.CAP_PROP_FPS)
    frames_to_skip = int(fps * seconds_per_frame)
    curr_frame=0

    # Loop through the video and extract frames at specified sampling rate
    while curr_frame < total_frames - 1:
        video.set(cv2.CAP_PROP_POS_FRAMES, curr_frame)
        success, frame = video.read()
        if not success:
            break
        _, buffer = cv2.imencode(".jpg", frame)
        base64Frames.append(base64.b64encode(buffer).decode("utf-8"))
        curr_frame += frames_to_skip
    video.release()

    # Extract audio from video
    audio_path = f"{base_video_path}.mp3"
    clip = VideoFileClip(video_path)
    clip.audio.write_audiofile(audio_path, bitrate="32k")
    clip.audio.close()
    clip.close()

    print(f"Extracted {len(base64Frames)} frames")
    print(f"Extracted audio to {audio_path}")
    return base64Frames, audio_path

# Extract 1 frame per second. You can adjust the `seconds_per_frame` parameter to change the sampling rate
base64Frames, audio_path = process_video(VIDEO_PATH, seconds_per_frame=1)
# Out:
# MoviePy - Writing audio in video.mp3
# MoviePy - Done.
# Extracted 16 frames
# Extracted audio to video.mp3

# %%
from IPython.display import Audio

## Display the frames and audio for context
display_handle = display(None, display_id=True)
for img in base64Frames:
    display_handle.update(Image(data=base64.b64decode(img.encode("utf-8")), width=600))
    time.sleep(0.025)

Audio(audio_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
response = client.chat.completions.create(
    model=MODEL,
    messages=[
    {"role": "system", "content": "You are generating a video summary. Please provide a summary of the video. Respond in Markdown."},
    {"role": "user", "content": [
        "These are the frames from the video.",
        *map(lambda x: {"type": "image_url",
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, base64Frames)
        ],
    }
    ],
    temperature=0,
)
print(response.choices[0].message.content)
# Out:
# ### Video Summary
#
# The video appears to be an advertisement for Google Chromecast, highlighting its ability to stream content from HBO GO to a TV. Here is a breakdown of the frames:
#
# 1. **Frames 1-2**: A tablet is shown playing a scene from "Game of Thrones" with a cup of coffee nearby.
# 2. **Frames 3-4**: A hand interacts with the tablet, showing a dragon from "Game of Thrones" breathing fire.
# 3. **Frames 5-9**: The scene transitions to a TV screen where the dragon's fire is shown in greater detail, with the text "FOR BIGGER BLAZES" overlaid on the screen.
# 4. **Frame 10**: A hand is shown plugging a Chromecast device into a TV.
# 5. **Frames 11-12**: The text "HBO GO right on your TV" and "Everything you love, now on your TV" appears.
# 6. **Frames 13-14**: The text "For $35. For everyone." is displayed.
# 7. **Frame 15**: The Chromecast logo is shown.
# 8. **Frame 16**: The video ends with the Google logo and the URL "google.com/chromecast".
#
# The advertisement emphasizes the ease and affordability of using Chromecast to stream popular shows like "Game of Thrones" from HBO GO directly to a TV.

# %%
# Transcribe the audio
transcription = client.audio.transcriptions.create(
    model="whisper-1",
    file=open(audio_path, "rb"),
)
## OPTIONAL: Uncomment the line below to print the transcription
#print("Transcript: ", transcription.text + "\n\n")

response = client.chat.completions.create(
    model=MODEL,
    messages=[
    {"role": "system", "content":"""You are generating a transcript summary. Create a summary of the provided transcription. Respond in Markdown."""},
    {"role": "user", "content": [
        {"type": "text", "text": f"The audio transcription is: {transcription.text}"}
        ],
    }
    ],
    temperature=0,
)
print(response.choices[0].message.content)
# Out:
# The transcription contains a single word in Russian: "Дракарис!" This is a transliteration of the word "Dracarys," which is a command used in the "Game of Thrones" series to instruct dragons to breathe fire.

# %%
## Generate a summary with visual and audio
response = client.chat.completions.create(
    model=MODEL,
    messages=[
    {"role": "system", "content":"""You are generating a video summary. Create a summary of the provided video and its transcript. Respond in Markdown"""},
    {"role": "user", "content": [
        "These are the frames from the video.",
        *map(lambda x: {"type": "image_url",
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, base64Frames),
        {"type": "text", "text": f"The audio transcription is: {transcription.text}"}
        ],
    }
],
    temperature=0,
)
print(response.choices[0].message.content)
# Out:
# ### Video Summary
#
# The video appears to be an advertisement for Google Chromecast, featuring a scene from the popular TV show "Game of Thrones" available on HBO GO.
#
# 1. **Initial Scene**: The video starts with a tablet on a wooden table, showing a scene from "Game of Thrones" with a character in front of a group of soldiers.
# 2. **Interaction**: A hand interacts with the tablet, swiping to reveal a dragon on the screen.
# 3. **Action Scene**: The dragon breathes fire, leading to a large explosion.
# 4. **Transition to TV**: The scene transitions to a TV screen showing the same explosion, emphasizing the dramatic effect.
# 5. **Text Overlay**: The text "FOR BIGGER BLAZES" appears on the TV screen, highlighting the enhanced viewing experience.
# 6. **Chromecast Device**: A hand is shown plugging a Chromecast device into a TV.
# 7. **Service Information**: The video ends with information about HBO GO being accessible on TV through Chromecast, with the text "Everything you love, now on your TV" and "For $35. For everyone."
# 8. **Branding**: The final frames show the Chromecast and Google logos, along with the website link for more information.
#
# The audio transcription "Дракарис!" (Dracarys) is a command used in "Game of Thrones" to instruct dragons to breathe fire, aligning with the fiery scenes shown in the video.

# %%
QUESTION = "Question: Why did the dragon breath fire?"

# %%
qa_visual_response = client.chat.completions.create(
    model=MODEL,
    messages=[
    {"role": "system", "content": "Use the video to answer the provided question. Respond in Markdown."},
    {"role": "user", "content": [
        "These are the frames from the video.",
        *map(lambda x: {"type": "image_url", "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, base64Frames),
        QUESTION
        ],
    }
    ],
    temperature=0,
)
print("Visual QA:\n" + qa_visual_response.choices[0].message.content)
# Out:
# Visual QA:
# The dragon breathed fire as part of a scene from the TV show "Game of Thrones," which is being shown in the video. The sequence is used to demonstrate the streaming capabilities of HBO GO on a larger screen using Chromecast. The fire-breathing dragon scene is likely chosen for its dramatic and visually impressive effect, emphasizing the tagline "FOR BIGGER BLAZES" and showcasing the enhanced viewing experience on a TV.

# %%
qa_audio_response = client.chat.completions.create(
    model=MODEL,
    messages=[
    {"role": "system", "content":"""Use the transcription to answer the provided question. Respond in Markdown."""},
    {"role": "user", "content": f"The audio transcription is: {transcription.text}. \n\n {QUESTION}"},
    ],
    temperature=0,
)
print("Audio QA:\n" + qa_audio_response.choices[0].message.content)
# Out:
# Audio QA:
# The dragon breathed fire because "Дракарис!" (Dracarys) is a command used in the "Game of Thrones" series to instruct dragons to breathe fire.

# %%
qa_both_response = client.chat.completions.create(
    model=MODEL,
    messages=[
    {"role": "system", "content":"""Use the video and transcription to answer the provided question."""},
    {"role": "user", "content": [
        "These are the frames from the video.",
        *map(lambda x: {"type": "image_url",
                        "image_url": {"url": f'data:image/jpg;base64,{x}', "detail": "low"}}, base64Frames),
                        {"type": "text", "text": f"The audio transcription is: {transcription.text}"},
        QUESTION
        ],
    }
    ],
    temperature=0,
)
print("Both QA:\n" + qa_both_response.choices[0].message.content)
# Out:
# Both QA:
# The dragon breathed fire in response to the command "Дракарис!" which is a command used in the show "Game of Thrones" to instruct dragons to breathe fire. This scene is being shown to demonstrate the streaming capabilities of HBO GO on a TV using Chromecast.
